# %% [markdown]
# ## introdution to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();
#remove the empty braces from the upperleft corner

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %%
# 1st method
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
#2nd method
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
#3rd method (recommended)
fig, ax=plt.subplots()
ax.plot(x, [50,100,200,350]);
#most used method

# %% [markdown]
# ## MATPLOTLIB EXAMPLE WORKFLOW

# %%
# 0. import matplotlib 

# %matplotlib inline
import matplotlib.pyplot as plt

#1. Prepare data

x=[1,2,3,4]
y=[6,12,18,24]

#2. Setup plot

fig,ax=plt.subplots(figsize=(2,5))

#3. Plot Data

ax.plot(x,y)

#4. Customize plot

ax.set(title='Simple Plot',xlabel='x-axis',ylabel='y-axis')

#5. Save and show

fig.savefig("../sample-plot.png")

# %% [markdown]
# ## Making figures with numpy arrays

# %%
import numpy as np

# %%
#puts regular diference between numbers
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#Plot the data and create a line plot
fig,ax=plt.subplots()
ax.plot(x,x**2);

# %% [markdown]
# ## Scatter plot

# %%
# Make scatter plot
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x));

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x));

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.tan(x));

# %% [markdown]
# ## Bar plot

# %%
# make a plot from dictionary
nut_butter_prices={"Almond butter":12,"Peanut butter":8,"Cashew butter":15}
fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="Nut Butter Store",ylabel="Price ($) per kg");

# %%
# For horizontal bar graphs, values are to be put in a list
fig,ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()));

# %% [markdown]
# ## Histogram

# %%
x=np.random.randn(1000)
fig,ax=plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
#Option 1
fig, ((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

#plot to each different axes
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
#Option 2
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

#plot to each different index

ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,0].set(ylabel="Price ($) per kg");
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas data frame

# %%
#import necessary packages
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#find cumulative sum and plot
ts=pd.Series(np.random.random(1000),
             index=pd.date_range("1/1/2020",periods=1000))
ts=ts.cumsum()
ts.plot();

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"]=car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
#plot for cumulative values in car sales
car_sales.plot(x="Sale Date",y="Total Sales");

# %%
car_sales["Price"]=car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
x=np.random.rand(10,4)
x
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.697714  0.926367  0.172291  0.236394
# 1  0.374805  0.146538  0.451644  0.107421
# 2  0.058823  0.608465  0.801904  0.255914
# 3  0.575954  0.419315  0.891952  0.889801
# 4  0.767202  0.190249  0.450751  0.854991
# 5  0.148185  0.529365  0.695933  0.844519
# 6  0.136786  0.890983  0.940524  0.981692
# 7  0.144546  0.002261  0.165521  0.976976
# 8  0.749583  0.983751  0.716887  0.271246
# 9  0.872190  0.269145  0.876434  0.863973

# %%
#plot a bar graph for random values
#type 1
df.plot.bar();

# %%
#type 2
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar");

# %%
#make a histogram
#type 1
car_sales["Odometer (KM)"].plot.hist();

# %%
#type 2
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
#make the blocks according to bins small or big
car_sales["Odometer (KM)"].plot.hist(bins=30);

# %%
heart_disease=pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=70);

# %%
heart_disease.plot.hist(figsize=(10,40), bins =40, subplots=True);

# %% [markdown]
# # Which one to use (pyplot or matplotlib OO method)
#
# ## 1. when using something quickly, use pyplot
# ## 2. When plotting advanced, use OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50=heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#Pyplot method
over_50.plot(kind="scatter",x="age",y="chol",c="target");

# %%
## OO method
fig,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",x="age",y="chol",c="target",ax=ax);

# %% [markdown]
# ## OO method from scratch

# %%
fig,ax=plt.subplots(figsize=(10,6))

#Plot the data
scatter=ax.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])

#Customize the plot
ax.set(title="Heart Disease and Cholestrol Levels",xlabel="Age",ylabel="Cholestrol")

#Add a legend
ax.legend(*scatter.legend_elements(),title="Target")

#Add a horizontal line
ax.axhline(over_50["chol"].mean(),linestyle="--");

# %%
fig,(ax0,ax1)=plt.subplots(nrows=1,ncols=2,figsize=(14,4))

#Plot the data
scatter=ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])

#Customize the plot
ax0.set(title="Heart Disease and Cholestrol Levels",xlabel="Age",ylabel="Cholestrol")

#Add a legend
ax0.legend(*scatter.legend_elements(),title="Target")

#Add a horizontal line
ax0.axhline(over_50["chol"].mean(),linestyle="--");



#Plot the data for ax1
scatter=ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"])

#Customize the plot
ax1.set(title="Heart Disease and Max.heart rate",xlabel="Age",ylabel="Max.heart rate")

#Add a legend
ax1.legend(*scatter.legend_elements(),title="Target")

#Add a horizontal line
ax1.axhline(over_50["thalach"].mean(),linestyle="--");

# %% [markdown]
# ## Customizing matplotlib

# %%
# checking different styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-white')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales["Price"].plot();

# %%
#Create some random data
x=np.random.randn(10,4)
x
# Out:
# array([[ 1.01813323, -1.60993321, -1.33950872, -0.62878502],
#        [ 0.39321753, -0.81558853, -0.50380733,  0.44584657],
#        [ 0.17818355, -0.84965938, -0.10783457, -0.36762474],
#        [ 0.83095831, -0.23720487, -1.94852845, -0.1897653 ],
#        [-0.06969412,  0.69020748,  1.62171879,  1.00082318],
#        [-0.11380275,  0.48863004,  0.82484197,  0.56208348],
#        [ 1.37407818,  0.32935385,  0.32109295,  0.50520106],
#        [-0.3990037 ,  0.33688115,  2.85073484, -0.02746504],
#        [ 0.58690906, -0.15413719, -0.25499922,  0.27764807],
#        [-1.28810183,  1.07504143,  0.74496363, -1.13401462]])

# %%
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  1.018133 -1.609933 -1.339509 -0.628785
# 1  0.393218 -0.815589 -0.503807  0.445847
# 2  0.178184 -0.849659 -0.107835 -0.367625
# 3  0.830958 -0.237205 -1.948528 -0.189765
# 4 -0.069694  0.690207  1.621719  1.000823
# 5 -0.113803  0.488630  0.824842  0.562083
# 6  1.374078  0.329354  0.321093  0.505201
# 7 -0.399004  0.336881  2.850735 -0.027465
# 8  0.586909 -0.154137 -0.254999  0.277648
# 9 -1.288102  1.075041  0.744964 -1.134015

# %%
ax=df.plot(kind="bar")

# %%
# Customize plot
x=df.plot(kind="bar")
#Add some labels and title
x.set(title="Random bar graph",xlabel="Row number",ylabel="Random number")
#Make the legend visible
x.legend().set_visible(True);

# %%
plt.style.use('seaborn-whitegrid')

fig,ax=plt.subplots(figsize=(10,6))

#Plot the data
scatter=ax.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],cmap="winter")

#Customize the plot
ax.set(title="Heart Disease and Cholestrol Levels",xlabel="Age",ylabel="Cholestrol")

#Add a legend
ax.legend(*scatter.legend_elements(),title="Target")

#Add a horizontal line
ax.axhline(over_50["chol"].mean(),linestyle="--");

# %%
fig,(ax0,ax1)=plt.subplots(nrows=1,ncols=2,figsize=(14,5))

#Plot the data
scatter=ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],cmap="winter")

#Customize the plot
ax0.set(title="Heart Disease and Cholestrol Levels",xlabel="Age",ylabel="Cholestrol")

#Add a legend
ax0.legend(*scatter.legend_elements(),title="Target")

#Add a horizontal line
ax0.axhline(over_50["chol"].mean(),linestyle="--");



#Plot the data for ax1
scatter=ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"],cmap="summer")

#Customize the plot
ax1.set(title="Heart Disease and Max.heart rate",xlabel="Age",ylabel="Max.heart rate")

#Add a legend
ax1.legend(*scatter.legend_elements(),title="Target")

#Add a horizontal line
ax1.axhline(over_50["thalach"].mean(),linestyle="--")
# Add a title to the entire plot
fig.suptitle("Heart Disease Analysis",fontsize=12,fontweight="bold");
